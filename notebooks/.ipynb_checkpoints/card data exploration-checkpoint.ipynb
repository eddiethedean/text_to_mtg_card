# %%
# for data exploration
import pandas as pd

# for connecting to card database
import sqlalchemy as sa

# for displaying card images
from IPython.display import Image
from IPython.core.display import HTML

# %%
engine = sa.create_engine('sqlite:///../data/AllPrintings.sqlite')
sa.inspect(engine).get_table_names()
# Out:
# ['cards',
#  'foreign_data',
#  'legalities',
#  'meta',
#  'rulings',
#  'set_translations',
#  'sets',
#  'sqlite_sequence',
#  'tokens']

# %%
df = pd.read_sql_table('cards', engine)
df
# Out:
#           id           artist asciiName attractionLights availability  \
# 0          1     Pete Venters      None             None   mtgo,paper
# 1          2     Pete Venters      None             None   mtgo,paper
# 2          3      Volkan Baǵa      None             None   mtgo,paper
# 3          4      Volkan Baǵa      None             None   mtgo,paper
# 4          5         Mark Zug      None             None   mtgo,paper
# ...      ...              ...       ...              ...          ...
# 76367  76368   Campbell White      None             None   mtgo,paper
# 76368  76369  Jason Rainville      None             None   mtgo,paper
# 76369  76370   Campbell White      None             None   mtgo,paper
# 76370  76371      Jonas De Ro      None             None   mtgo,paper
# 76371  76372      Colin Boyer      None             None   mtgo,paper
#
#       boosterTypes borderColor cardKingdomEtchedId cardKingdomFoilId  \
# 0            draft       black                None              None
# 1            draft       black                None            123087
# 2            draft       black                None              None
# 3            draft       black                None            123088
# 4            draft       black                None              None
# ...            ...         ...                 ...               ...
# 76367         None       black                None            238366
# 76368         None       black                None            238367
# 76369         None       black                None            238368
# 76370         None       black                None            238369
# 76371         None       black                None            238370
#
#       cardKingdomId  ... supertypes tcgplayerEtchedProductId  \
# 0            122719  ...       None                     None
# 1              None  ...       None                     None
# 2            122720  ...       None                     None
# 3              None  ...       None                     None
# 4            122721  ...       None                     None
# ...             ...  ...        ...                      ...
# 76367        237879  ...       None                     None
# 76368        237880  ...       None                     None
# 76369        237881  ...       None                     None
# 76370        237882  ...       None                     None
# 76371        237883  ...       None                     None
#
#       tcgplayerProductId                                               text  \
# 0                  15032  First strike (This creature deals combat damag...
# 1                  15032  First strike (This creature deals combat damag...
# 2                  15033  Flying\nWhen Angel of Mercy enters the battlef...
# 3                  15033  Flying\nWhen Angel of Mercy enters the battlef...
# 4                  15035  Target creature gets +3/+3 and gains flying un...
# ...                  ...                                                ...
# 76367             222847  Kicker {1}{U} (You may pay an additional {1}{U...
# 76368             222848  Kicker {2}{B} (You may pay an additional {2}{B...
# 76369             222850  Kicker {5} (You may pay an additional {5} as y...
# 76370             222851  Sacrifice a land. Search your library for up t...
# 76371             222853              Other Warriors you control get +1/+1.
#
#       toughness                      type     types  \
# 0             4   Creature — Human Cleric  Creature
# 1             4   Creature — Human Cleric  Creature
# 2             3          Creature — Angel  Creature
# 3             3          Creature — Angel  Creature
# 4          None                   Sorcery   Sorcery
# ...         ...                       ...       ...
# 76367      None                   Instant   Instant
# 76368      None                   Sorcery   Sorcery
# 76369      None                   Sorcery   Sorcery
# 76370      None                   Instant   Instant
# 76371         3  Creature — Human Warrior  Creature
#
#                                        uuid  \
# 0      5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# 1      b7c19924-b4bf-56fc-aa73-f586e940bd42
# 2      57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 3      8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a
# 4      55bd38ca-dc73-5c06-8f80-a6ddd2f44382
# ...                                     ...
# 76367  3f492516-7767-5ed7-a1d4-e3f7c06aee2f
# 76368  3f9a0369-5fe7-5aee-85fe-3cfaacd275af
# 76369  97577e9e-69a9-5a8b-9c24-a72703790046
# 76370  deb51cbd-b890-5b2d-9d6f-7b896e16c6fd
# 76371  46407d93-df48-5161-95fe-f24086746663
#
#                                  variations     watermark
# 0      b7c19924-b4bf-56fc-aa73-f586e940bd42          None
# 1      5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c          None
# 2      8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a          None
# 3      57aaebc1-850c-503d-9f6e-bb8d00d8bf7c          None
# 4      c5655330-5131-5f40-9d3e-0549d88c6e9e          None
# ...                                     ...           ...
# 76367  dd604910-0e81-5d56-b022-e08f21de0879  planeswalker
# 76368  d947d9cd-f855-5496-b5de-88006b49865f  planeswalker
# 76369  dbd65728-bba8-536e-a908-5dfa56068dcb  planeswalker
# 76370  7ef6cffb-335a-5831-8319-20b6a020f1c4  planeswalker
# 76371  f3434acf-7796-572c-a889-487c84cf7948  planeswalker
#
# [76372 rows x 92 columns]

# %%
df.dropna(subset='multiverseId', inplace=True)

# %%
row = df.iloc[100]
dict(row)
# Out:
# {'id': 142,
#  'artist': 'Christopher Moeller',
#  'asciiName': None,
#  'attractionLights': None,
#  'availability': 'mtgo,paper',
#  'boosterTypes': 'draft',
#  'borderColor': 'black',
#  'cardKingdomEtchedId': None,
#  'cardKingdomFoilId': None,
#  'cardKingdomId': '122819',
#  'cardParts': None,
#  'cardsphereId': '522',
#  'colorIdentity': 'U',
#  'colorIndicator': None,
#  'colors': 'U',
#  'convertedManaCost': 1.0,
#  'duelDeck': None,
#  'edhrecRank': 8461.0,
#  'faceConvertedManaCost': nan,
#  'faceFlavorName': None,
#  'faceManaValue': nan,
#  'faceName': None,
#  'finishes': 'nonfoil',
#  'flavorName': None,
#  'flavorText': None,
#  'frameEffects': None,
#  'frameVersion': '2003',
#  'hand': None,
#  'hasAlternativeDeckLimit': 0,
#  'hasContentWarning': 0,
#  'hasFoil': 0,
#  'hasNonFoil': 1,
#  'isAlternative': 0,
#  'isFullArt': 0,
#  'isFunny': 0,
#  'isOnlineOnly': 0,
#  'isOversized': 0,
#  'isPromo': 0,
#  'isRebalanced': 0,
#  'isReprint': 1,
#  'isReserved': 0,
#  'isStarter': 0,
#  'isStorySpotlight': 0,
#  'isTextless': 0,
#  'isTimeshifted': 0,
#  'keywords': 'Enchant',
#  'language': 'English',
#  'layout': 'normal',
#  'leadershipSkills': None,
#  'life': None,
#  'loyalty': None,
#  'manaCost': '{U}',
#  'manaValue': 1.0,
#  'mcmId': '16265',
#  'mcmMetaId': '4759',
#  'mtgArenaId': None,
#  'mtgjsonV4Id': 'a460550a-c24d-5abc-8b74-ee2f39452ff8',
#  'mtgoFoilId': '27193',
#  'mtgoId': '27192',
#  'multiverseId': '134764',
#  'name': 'Robe of Mirrors',
#  'number': '101',
#  'originalPrintings': None,
#  'originalReleaseDate': None,
#  'originalText': "Enchant creature (Target a creature as you play this. This card comes into play attached to that creature.)\nEnchanted creature has shroud. (It can't be the target of spells or abilities.)",
#  'originalType': 'Enchantment - Aura',
#  'otherFaceIds': None,
#  'power': None,
#  'printings': '10E,EXO',
#  'promoTypes': None,
#  'purchaseUrls': "{'cardKingdom': 'https://mtgjson.com/links/127eba43473795d3', 'cardmarket': 'https://mtgjson.com/links/85117083ab85bf93', 'tcgplayer': 'https://mtgjson.com/links/98c25865924307d1'}",
#  'rarity': 'common',
#  'rebalancedPrintings': None,
#  'relatedCards': None,
#  'scryfallId': '9948fcc3-6e95-4b39-accd-a4083fff1244',
#  'scryfallIllustrationId': 'b167057a-bdbf-4c91-9c32-5fa0e939a878',
#  'scryfallOracleId': '093a20e5-ff14-41c7-b16c-1f745ddf6942',
#  'securityStamp': None,
#  'setCode': '10E',
#  'side': None,
#  'signature': None,
#  'subtypes': 'Aura',
#  'supertypes': None,
#  'tcgplayerEtchedProductId': None,
#  'tcgplayerProductId': '15282',
#  'text': "Enchant creature (Target a creature as you cast this. This card enters the battlefield attached to that creature.)\nEnchanted creature has shroud. (It can't be the target of spells or abilities.)",
#  'toughness': None,
#  'type': 'Enchantment — Aura',
#  'types': 'Enchantment',
#  'uuid': '9626b37d-3a04-5cd6-a636-943981354e2b',
#  'variations': '23aabc91-9146-5367-9cce-4fe955861abb',
#  'watermark': None}

# %%
multiverse_id = row['multiverseId']

def card_url(multiverse_id: str) -> str:
    return f'http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid={multiverse_id}&type=card'

def card_image(multiverse_id: str) -> Image:
    url = card_url(multiverse_id)
    print(url)
    return Image(url=url)

card_image(multiverse_id)
# Out:
# http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=134764&type=card
# <img src="http://gatherer.wizards.com/Handlers/Image.ashx?multiverseid=134764&type=card"/>

# %%
bolts = df[df['name'] == "Lightning Bolt"]
bolts
# Out:
#           id               artist asciiName attractionLights  \
# 669      670     Christopher Rush      None             None
# 926      927  Christopher Moeller      None             None
# 1170    1171         Chuck Lukacs      None             None
# 2528    2529     Christopher Rush      None             None
# 3876    3877     Christopher Rush      None             None
# 6236    6237  Christopher Moeller      None             None
# 11400  11401     Christopher Rush      None             None
# 15761  15762        Irina Nordsol      None             None
# 15982  15983           Phil Stone      None             None
# 24276  24277  Christopher Moeller      None             None
# 27466  27467  Christopher Moeller      None             None
# 31821  31822  Christopher Moeller      None             None
# 33007  33008  Christopher Moeller      None             None
# 35119  35120     Christopher Rush      None             None
# 35415  35416     Christopher Rush      None             None
# 36457  36458  Christopher Moeller      None             None
# 36709  36710  Christopher Moeller      None             None
# 40883  40884     Christopher Rush      None             None
# 43643  43644  Christopher Moeller      None             None
# 50140  50141  Christopher Moeller      None             None
# 64070  64071         Noah Bradley      None             None
# 64071  64072        Brigitte Roka      None             None
# 64072  64073       Robbie Trevino      None             None
# 64073  64074        Alexis Ziritt      None             None
# 66205  66206      Anato Finnstark      None             None
#
#            availability boosterTypes borderColor cardKingdomEtchedId  \
# 669               paper        draft       white                None
# 926          mtgo,paper        draft       black                None
# 1170              paper         None  borderless                None
# 2528              paper        draft       white                None
# 3876              paper        draft       white                None
# 6236         mtgo,paper        draft       black                None
# 11400             paper         None       white                None
# 15761             paper        draft       black                None
# 15982             paper         None       black                None
# 24276             paper         None       black                None
# 27466             paper         None       black                None
# 31821             arena         None       black                None
# 33007             paper        draft       black                None
# 35119             paper        draft       black                None
# 35415             paper        draft       black                None
# 36457        mtgo,paper        draft       black                None
# 36709        mtgo,paper        draft       black                None
# 40883              mtgo        draft       black                None
# 43643        mtgo,paper        draft       black                None
# 50140        mtgo,paper         None       black                None
# 64070             paper         None       black                None
# 64071             paper         None       black                None
# 64072             paper         None       black                None
# 64073             paper         None       black                None
# 66205  arena,mtgo,paper         None  borderless              244269
#
#       cardKingdomFoilId cardKingdomId  ... supertypes  \
# 669                None         13147  ...       None
# 926              263552        262956  ...       None
# 1170             263387        262975  ...       None
# 2528               None         26151  ...       None
# 3876               None         10190  ...       None
# 6236             217405        217140  ...       None
# 11400              None         70344  ...       None
# 15761            261363        260665  ...       None
# 15982            261743        260678  ...       None
# 24276              None        212655  ...       None
# 27466              None        267808  ...       None
# 31821              None          None  ...       None
# 33007              None        235007  ...       None
# 35119              None         64144  ...       None
# 35415              None         53145  ...       None
# 36457            127330        127084  ...       None
# 36709            131781        131524  ...       None
# 40883              None          None  ...       None
# 43643            201339        201037  ...       None
# 50140            132589          None  ...       None
# 64070            233842          None  ...       None
# 64071            233844          None  ...       None
# 64072            233845          None  ...       None
# 64073            233843          None  ...       None
# 66205            244067        243888  ...       None
#
#       tcgplayerEtchedProductId tcgplayerProductId  \
# 669                       None               9121
# 926                       None             276484
# 1170                      None             276485
# 2528                      None               1479
# 3876                      None               1825
# 6236                      None             161480
# 11400                     None              37503
# 15761                     None             267051
# 15982                     None             267061
# 24276                     None             132266
# 27466                     None             448525
# 31821                     None               None
# 33007                     None             216484
# 35119                     None               1174
# 35415                     None               8819
# 36457                     None              32656
# 36709                     None              35427
# 40883                     None               None
# 43643                     None              98503
# 50140                     None              38681
# 64070                     None             214899
# 64071                     None             214901
# 64072                     None             214900
# 64073                     None             214898
# 66205                   235144             235143
#
#                                                text toughness     type  \
# 669    Lightning Bolt deals 3 damage to any target.      None  Instant
# 926    Lightning Bolt deals 3 damage to any target.      None  Instant
# 1170   Lightning Bolt deals 3 damage to any target.      None  Instant
# 2528   Lightning Bolt deals 3 damage to any target.      None  Instant
# 3876   Lightning Bolt deals 3 damage to any target.      None  Instant
# 6236   Lightning Bolt deals 3 damage to any target.      None  Instant
# 11400  Lightning Bolt deals 3 damage to any target.      None  Instant
# 15761  Lightning Bolt deals 3 damage to any target.      None  Instant
# 15982  Lightning Bolt deals 3 damage to any target.      None  Instant
# 24276  Lightning Bolt deals 3 damage to any target.      None  Instant
# 27466  Lightning Bolt deals 3 damage to any target.      None  Instant
# 31821  Lightning Bolt deals 3 damage to any target.      None  Instant
# 33007  Lightning Bolt deals 3 damage to any target.      None  Instant
# 35119  Lightning Bolt deals 3 damage to any target.      None  Instant
# 35415  Lightning Bolt deals 3 damage to any target.      None  Instant
# 36457  Lightning Bolt deals 3 damage to any target.      None  Instant
# 36709  Lightning Bolt deals 3 damage to any target.      None  Instant
# 40883  Lightning Bolt deals 3 damage to any target.      None  Instant
# 43643  Lightning Bolt deals 3 damage to any target.      None  Instant
# 50140  Lightning Bolt deals 3 damage to any target.      None  Instant
# 64070  Lightning Bolt deals 3 damage to any target.      None  Instant
# 64071  Lightning Bolt deals 3 damage to any target.      None  Instant
# 64072  Lightning Bolt deals 3 damage to any target.      None  Instant
# 64073  Lightning Bolt deals 3 damage to any target.      None  Instant
# 66205  Lightning Bolt deals 3 damage to any target.      None  Instant
#
#          types                                  uuid  \
# 669    Instant  d944340c-4fa8-5bd1-8abd-ad42cb1d2ae4
# 926    Instant  0aa4288b-47ee-5d3b-8b81-5479779a8b7b
# 1170   Instant  190a854f-6657-59fb-a551-4bf99e4a5905
# 2528   Instant  983bb171-9ffa-5252-b7ed-49b3f6988369
# 3876   Instant  61aa652c-e307-5b1c-9332-9025ebbcb504
# 6236   Instant  88d7451f-97a3-51cc-8e8e-722c951d783b
# 11400  Instant  9d662600-92b0-574a-8d4b-183bb9581536
# 15761  Instant  0b0ac66e-a46b-5a7d-ba53-07d6c06e9561
# 15982  Instant  578de53b-151a-5082-9c0a-81409d544162
# 24276  Instant  be977738-775e-52d6-a151-eaae951762a4
# 27466  Instant  cc53a850-484b-51e3-8cb7-5cd332da2ae1
# 31821  Instant  9fa26a2d-e60e-59de-87d5-c6019bfe4e32
# 33007  Instant  f5e9103b-8b91-54fc-88bc-57ca415bdb44
# 35119  Instant  c65fcd18-dc47-50d4-bdb1-518bbf0ef820
# 35415  Instant  50654227-37ac-56b0-a2fb-a1a804dc9133
# 36457  Instant  78380203-7623-50bc-ab48-577cd655ee9a
# 36709  Instant  6ca7af0b-4b6a-59ba-90be-6da4f62bcff1
# 40883  Instant  1fd3d506-7308-55cd-b599-aaa915c574ff
# 43643  Instant  90382a47-3cdf-511d-8965-342d00e37672
# 50140  Instant  8cc1ad54-423e-5851-b201-baef7b893718
# 64070  Instant  26bb9b31-fc82-54b3-b13e-56dd1dba312a
# 64071  Instant  fa340683-e523-511d-8c98-ea498d69da0c
# 64072  Instant  20446d8e-c01e-5d05-93c1-488efb00087c
# 64073  Instant  6787846a-9e3d-52cb-a190-24f29331c62d
# 66205  Instant  952756ad-89fd-5524-95dc-baaa99cdbc19
#
#                                               variations  watermark
# 669                                                 None       None
# 926                 190a854f-6657-59fb-a551-4bf99e4a5905       None
# 1170                0aa4288b-47ee-5d3b-8b81-5479779a8b7b       None
# 2528                                                None       None
# 3876                                                None       None
# 6236                                                None  set (LEA)
# 11400                                               None       None
# 15761               578de53b-151a-5082-9c0a-81409d544162       None
# 15982               0b0ac66e-a46b-5a7d-ba53-07d6c06e9561       None
# 24276                                               None       None
# 27466                                               None       None
# 31821                                               None       None
# 33007                                               None       None
# 35119                                               None       None
# 35415                                               None       None
# 36457                                               None       None
# 36709                                               None       None
# 40883                                               None       None
# 43643                                               None       None
# 50140                                               None       None
# 64070  fa340683-e523-511d-8c98-ea498d69da0c,20446d8e-...       None
# 64071  26bb9b31-fc82-54b3-b13e-56dd1dba312a,20446d8e-...       None
# 64072  26bb9b31-fc82-54b3-b13e-56dd1dba312a,fa340683-...       None
# 64073  26bb9b31-fc82-54b3-b13e-56dd1dba312a,fa340683-...       None
# 66205               440af151-df38-5152-979d-84009ab7e1a7       None
#
# [25 rows x 92 columns]

# %%
features = ['artist', 'borderColor', 'colorIdentity',
    'colorIndicator', 'colors', 'convertedManaCost',
    'frameVersion', 'isFullArt', 'isTextless',
    'isTimeshifted', 'keywords', 'loyalty', 'manaCost',
    'manaValue', 'name', 'number', 'originalText', 
    'originalType', 'power', 'toughness', 'rarity',
    'securityStamp', 'setCode', 'subtypes',
    'supertypes', 'text', 'toughness', 'type',
    'types', 'watermark']

cards = df[features]
cards
# Out:
#               artist borderColor colorIdentity colorIndicator colors  \
# 0       Pete Venters       black             W           None      W
# 2        Volkan Baǵa       black             W           None      W
# 4           Mark Zug       black             W           None      W
# 6         Jim Murray       black             W           None      W
# 7          John Avon       black             W           None      W
# ...              ...         ...           ...            ...    ...
# 76360  Adam Paquette       black             W           None   None
# 76361      Tianhua X       black             U           None   None
# 76362  Adam Paquette       black             B           None   None
# 76363     Sam Burley       black             R           None   None
# 76364  Adam Paquette       black             G           None   None
#
#        convertedManaCost frameVersion  isFullArt  isTextless  isTimeshifted  \
# 0                    7.0         2003          0           0              0
# 2                    5.0         2003          0           0              0
# 4                    3.0         2003          0           0              0
# 6                    5.0         2003          0           0              0
# 7                    2.0         2003          0           0              0
# ...                  ...          ...        ...         ...            ...
# 76360                0.0         2015          0           0              0
# 76361                0.0         2015          0           0              0
# 76362                0.0         2015          0           0              0
# 76363                0.0         2015          0           0              0
# 76364                0.0         2015          0           0              0
#
#        ...    rarity securityStamp setCode      subtypes supertypes  \
# 0      ...  uncommon          None     10E  Human,Cleric       None
# 2      ...  uncommon          None     10E         Angel       None
# 4      ...    common          None     10E          None       None
# 6      ...      rare          None     10E          None       None
# 7      ...    common          None     10E          Wall       None
# ...    ...       ...           ...     ...           ...        ...
# 76360  ...    common          None     ZNR        Plains      Basic
# 76361  ...    common          None     ZNR        Island      Basic
# 76362  ...    common          None     ZNR         Swamp      Basic
# 76363  ...    common          None     ZNR      Mountain      Basic
# 76364  ...    common          None     ZNR        Forest      Basic
#
#                                                     text toughness  \
# 0      First strike (This creature deals combat damag...         4
# 2      Flying\nWhen Angel of Mercy enters the battlef...         3
# 4      Target creature gets +3/+3 and gains flying un...      None
# 6      Whenever a creature enters the battlefield und...      None
# 7         Defender (This creature can't attack.)\nFlying         4
# ...                                                  ...       ...
# 76360                                    ({T}: Add {W}.)      None
# 76361                                    ({T}: Add {U}.)      None
# 76362                                    ({T}: Add {B}.)      None
# 76363                                    ({T}: Add {R}.)      None
# 76364                                    ({T}: Add {G}.)      None
#
#                           type        types watermark
# 0      Creature — Human Cleric     Creature      None
# 2             Creature — Angel     Creature      None
# 4                      Sorcery      Sorcery      None
# 6                  Enchantment  Enchantment      None
# 7              Creature — Wall     Creature      None
# ...                        ...          ...       ...
# 76360      Basic Land — Plains         Land      None
# 76361      Basic Land — Island         Land      None
# 76362       Basic Land — Swamp         Land      None
# 76363    Basic Land — Mountain         Land      None
# 76364      Basic Land — Forest         Land      None
#
# [51186 rows x 30 columns]

# %%
cards.iloc[2]
# Out:
# artist                                                        Mark Zug
# borderColor                                                      black
# colorIdentity                                                        W
# colorIndicator                                                    None
# colors                                                               W
# convertedManaCost                                                  3.0
# frameVersion                                                      2003
# isFullArt                                                            0
# isTextless                                                           0
# isTimeshifted                                                        0
# keywords                                                          None
# loyalty                                                           None
# manaCost                                                        {2}{W}
# manaValue                                                          3.0
# name                                                  Angelic Blessing
# number                                                               3
# originalText         Target creature gets +3/+3 and gains flying un...
# originalType                                                   Sorcery
# power                                                             None
# toughness                                                         None
# rarity                                                          common
# securityStamp                                                     None
# setCode                                                            10E
# subtypes                                                          None
# supertypes                                                        None
# text                 Target creature gets +3/+3 and gains flying un...
# toughness                                                         None
# type                                                           Sorcery
# types                                                          Sorcery
# watermark                                                         None
# Name: 4, dtype: object

# %%
colors = {'W': 'white', 'U': 'blue', 'B': 'black', 'R': 'red', 'G': 'green'}
def cost(cost: str) -> str:
    return cost.replace('{', '').replace('}', '')

def frame()

def description(row: pd.Series) -> str:
    color_type_cost = f'A {colors[row.colorIdentity]} {row.types} with mana cost {cost(row.manaCost)} '
    border_frame = f'with {row.borderColor} border and '
    if row.power is None:
        return color_type_cost + line2
        
description(cards.iloc[2])
# Out:
# 'A white Sorcery with mana cost 2W'

# %%
df.frameVersion.value_counts()
# Out:
# 2015      26732
# 2003      12801
# 1997       8296
# 1993       3276
# future       81
# Name: frameVersion, dtype: int64
